# %%
from marc_dataframes import marc, zephyr

json = [
    zephyr.load_from_api('txu.059173018498868'),
    zephyr.load_from_api('gri.ark:/13960/t91875m5j'),
    zephyr.load_from_api('mdp.39015022391018')
]

data = zephyr.ZephyrTransformer(marc.select(
    marc.AllFields
)).transform(json)

display(data)
# Out:
#                                                                         100  \
# txu.059173018498868       {'ind1': '1', 'ind2': ' ', 'subfields': [{'a':...
# gri.ark:/13960/t91875m5j  {'ind1': '1', 'ind2': ' ', 'subfields': [{'a':...
# mdp.39015022391018        {'ind1': '1', 'ind2': ' ', 'subfields': [{'a':...
#
#                          110 130 210 222 240 242 243  \
# txu.059173018498868
# gri.ark:/13960/t91875m5j
# mdp.39015022391018
#
#                                                                         245  \
# txu.059173018498868       {'ind1': '1', 'ind2': '4', 'subfields': [{'a':...
# gri.ark:/13960/t91875m5j  {'ind1': '1', 'ind2': '3', 'subfields': [{'a':...
# mdp.39015022391018        {'ind1': '1', 'ind2': '0', 'subfields': [{'a':...
#
#                          246 ... 250 254 255 256 257 258  \
# txu.059173018498868          ...
# gri.ark:/13960/t91875m5j     ...
# mdp.39015022391018           ...
#
#                                                                         260  \
# txu.059173018498868       {'ind1': ' ', 'ind2': ' ', 'subfields': [{'a':...
# gri.ark:/13960/t91875m5j  {'ind1': ' ', 'ind2': ' ', 'subfields': [{'a':...
# mdp.39015022391018        {'ind1': ' ', 'ind2': ' ', 'subfields': [{'a':...
#
#                          263 264 270
# txu.059173018498868
# gri.ark:/13960/t91875m5j
# mdp.39015022391018
#
# [3 rows x 21 columns]
